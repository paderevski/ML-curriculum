# %% [markdown]
# # Training CiFAR with Keras
#
# This simple example demonstrates how to plug TensorFlow Datasets (TFDS) into a Keras model.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'

# %% [markdown]
# ## Imports and setup
# We use `tensorflow` for modeling and `tensorflow_datasets` (TFDS) for convenient dataset loading + metadata. Make sure the notebook kernel points to the environment where TensorFlow is installed.

# %% [markdown]
# ## Step 1: Create your input pipeline
#
# Start by building an efficient input pipeline using advices from:
# * The [Performance tips](https://www.tensorflow.org/datasets/performances) guide
# * The [Better performance with the `tf.data` API](https://www.tensorflow.org/guide/data_performance#optimize_performance) guide

# %% [markdown]
# ### Load a dataset
#
# Load the MNIST dataset with the following arguments:
#
# * `shuffle_files=True`: The MNIST data is only stored in a single file, but for larger datasets with multiple files on disk, it's good practice to shuffle them when training.
# * `as_supervised=True`: Returns a tuple `(img, label)` instead of a dictionary `{'image': img, 'label': label}`.

# %%
(ods_train, ods_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)
# Out:
# 2026-05-18 23:15:34.317670: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4
# 2026-05-18 23:15:34.317690: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 24.00 GB
# 2026-05-18 23:15:34.317696: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 8.00 GB
# 2026-05-18 23:15:34.317726: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-05-18 23:15:34.317735: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ### Dataset info
# `ds_info` includes split sizes, feature shapes, and class labels. We’ll use it later for class names and sanity checks.

# %% [markdown]
# ### Build a training pipeline
#
# Apply the following transformations:
#
# * `tf.data.Dataset.map`: TFDS provide images of type `tf.uint8`, while the model expects `tf.float32` in the range [0,1]. Therefore, you need to normalize images.
# * `tf.data.Dataset.cache` As you fit the dataset in memory, cache it before shuffling for a better performance.<br/>
# __Note:__ Random transformations should be applied after caching.
# * `tf.data.Dataset.shuffle`: For true randomness, set the shuffle buffer to the full dataset size.<br/>
# __Note:__ For large datasets that can't fit in memory, use `buffer_size=1000` if your system allows it.
# * `tf.data.Dataset.batch`: Batch elements of the dataset after shuffling to get unique batches at each epoch. You can increase the batch size to speed up training, depending on the amount of GPU memory.
# * `tf.data.Dataset.prefetch`: It is good practice to end the pipeline by prefetching [for performance](https://www.tensorflow.org/guide/data_performance#prefetching).

# %%
def normalize_img(image, label):
  """Normalizes images: `uint8` -> `float32`."""
  return tf.cast(image, tf.float32) / 255., label # type: ignore

ds_train = ods_train.map(
    normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.cache()
ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples)
ds_train = ds_train.batch(512)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ### Why these pipeline steps?
# - **Normalize** to scale pixels to $[0,1]$ for stable training.
# - **Cache** to avoid repeated disk reads.
# - **Shuffle** for better randomness each epoch.
# - **Batch** to leverage vectorization on GPU.
# - **Prefetch** to overlap data loading with model execution.

# %% [markdown]
# ## EDA

# %% [markdown]
# Look at some sample images. Note the way we get the class names from the ds_info dataset and use an iterator to get data from the training set in one batch.

# %%
# Display a sample of images from the training set with their labels
class_names = ds_info.features['label'].names

# Take a batch of images and labels
sample_images, sample_labels = next(iter(ods_train.batch(16)))

# Create a plot
plt.figure(figsize=(12, 8))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(sample_images[i].numpy())
    plt.title(class_names[sample_labels[i].numpy()])
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 2026-05-18 23:15:45.674703: W tensorflow/core/kernels/data/cache_dataset_ops.cc:858] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# Use EDA to confirm shapes, class balance, and a few example images before training. This helps catch preprocessing bugs early.

# %% [markdown]
# ### Build an evaluation pipeline
#
# Your testing pipeline is similar to the training pipeline with small differences:
#
#  * You don't need to call `tf.data.Dataset.shuffle`.
#  * Caching is done after batching because batches can be the same between epochs.

# %%
ds_test = ods_test.map(
    normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_test = ds_test.batch(128)
ds_test = ds_test.cache()
ds_test = ds_test.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ## Step 2: Create and train the model
#
# Plug the TFDS input pipeline into a simple Keras model, compile the model, and train it.

# %% [markdown]
# ### Baseline model
# Start simple: a flattened input and a few dense layers. This sets a reference point before adding regularization or augmentation.

# %%
# Create the Model
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(), # turn the 2D images each into one vector
  tf.keras.layers.Dense(128, activation='leaky_relu'), # a layer with 128 nodes
  tf.keras.layers.Dense(10) # the final layer, one node for each class
])

# Compile the Model
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001), # how exactly does gradient descent take a step and what is the step size
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), # the correct loss function for categorical data
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()], # report accuracy while training
)

# Run the model. Save history for further analysis
history = model.fit(
    ds_train, # the training set
    epochs=30, # number of epochs (full pass through entire training set)
    validation_data=ds_test, # the test set to use while training
)
# Out:
# Epoch 1/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1424 - sparse_categorical_accuracy: 0.2715 - val_loss: 1.8701 - val_sparse_categorical_accuracy: 0.3405
# Epoch 2/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8354 - sparse_categorical_accuracy: 0.3540 - val_loss: 1.8086 - val_sparse_categorical_accuracy: 0.3686
# Epoch 3/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7785 - sparse_categorical_accuracy: 0.3752 - val_loss: 1.7552 - val_sparse_categorical_accuracy: 0.3913
# Epoch 4/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7379 - sparse_categorical_accuracy: 0.3884 - val_loss: 1.7203 - val_sparse_categorical_accuracy: 0.3952
# Epoch 5/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.7098 - sparse_categorical_accuracy: 0.3993 - val_loss: 1.7033 - val_sparse_categorical_accuracy: 0.4014
# Epoch 6/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6808 - sparse_categorical_accuracy: 0.4126 - val_loss: 1.6767 - val_sparse_categorical_accuracy: 0.4122
# Epoch 7/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6530 - sparse_categorical_accuracy: 0.4224 - val_loss: 1.6578 - val_sparse_categorical_accuracy: 0.4167
# Epoch 8/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6283 - sparse_categorical_accuracy: 0.4300 - val_loss: 1.6558 - val_sparse_categorical_accuracy: 0.4152
# Epoch 9/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6085 - sparse_categorical_accuracy: 0.4366 - val_loss: 1.6500 - val_sparse_categorical_accuracy: 0.4234
# Epoch 10/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6001 - sparse_categorical_accuracy: 0.4396 - val_loss: 1.5947 - val_sparse_categorical_accuracy: 0.4433
# Epoch 11/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5775 - sparse_categorical_accuracy: 0.4483 - val_loss: 1.5878 - val_sparse_categorical_accuracy: 0.4434
# Epoch 12/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5659 - sparse_categorical_accuracy: 0.4499 - val_loss: 1.5825 - val_sparse_categorical_accuracy: 0.4387
# Epoch 13/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5462 - sparse_categorical_accuracy: 0.4599 - val_loss: 1.5810 - val_sparse_categorical_accuracy: 0.4452
# Epoch 14/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5306 - sparse_categorical_accuracy: 0.4646 - val_loss: 1.5572 - val_sparse_categorical_accuracy: 0.4479
# Epoch 15/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5232 - sparse_categorical_accuracy: 0.4656 - val_loss: 1.5490 - val_sparse_categorical_accuracy: 0.4578
# Epoch 16/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5112 - sparse_categorical_accuracy: 0.4707 - val_loss: 1.5552 - val_sparse_categorical_accuracy: 0.4459
# Epoch 17/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4994 - sparse_categorical_accuracy: 0.4741 - val_loss: 1.5328 - val_sparse_categorical_accuracy: 0.4649
# Epoch 18/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4777 - sparse_categorical_accuracy: 0.4849 - val_loss: 1.5406 - val_sparse_categorical_accuracy: 0.4558
# Epoch 19/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4706 - sparse_categorical_accuracy: 0.4866 - val_loss: 1.5166 - val_sparse_categorical_accuracy: 0.4593
# Epoch 20/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4651 - sparse_categorical_accuracy: 0.4868 - val_loss: 1.5280 - val_sparse_categorical_accuracy: 0.4543
# Epoch 21/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4651 - sparse_categorical_accuracy: 0.4873 - val_loss: 1.5025 - val_sparse_categorical_accuracy: 0.4727
# Epoch 22/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4486 - sparse_categorical_accuracy: 0.4931 - val_loss: 1.5320 - val_sparse_categorical_accuracy: 0.4558
# Epoch 23/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4380 - sparse_categorical_accuracy: 0.4977 - val_loss: 1.4882 - val_sparse_categorical_accuracy: 0.4747
# Epoch 24/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4276 - sparse_categorical_accuracy: 0.4993 - val_loss: 1.4883 - val_sparse_categorical_accuracy: 0.4702
# Epoch 25/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4271 - sparse_categorical_accuracy: 0.4996 - val_loss: 1.5349 - val_sparse_categorical_accuracy: 0.4587
# Epoch 26/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4238 - sparse_categorical_accuracy: 0.5005 - val_loss: 1.4939 - val_sparse_categorical_accuracy: 0.4651
# Epoch 27/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4003 - sparse_categorical_accuracy: 0.5111 - val_loss: 1.5028 - val_sparse_categorical_accuracy: 0.4657
# Epoch 28/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4109 - sparse_categorical_accuracy: 0.5047 - val_loss: 1.4832 - val_sparse_categorical_accuracy: 0.4804
# Epoch 29/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3950 - sparse_categorical_accuracy: 0.5108 - val_loss: 1.4884 - val_sparse_categorical_accuracy: 0.4697
# Epoch 30/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3877 - sparse_categorical_accuracy: 0.5136 - val_loss: 1.4937 - val_sparse_categorical_accuracy: 0.4646

# %% [markdown]
# Define a function to show the training curves using the history from a training session

# %%
import matplotlib.pyplot as plt

def show_training_curves(history):
  acc = history.history['sparse_categorical_accuracy']
  val_acc = history.history['val_sparse_categorical_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(len(acc))

  plt.figure(figsize=(12, 4))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.grid(True)

  plt.subplot(1, 2, 2)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.grid(True)

  plt.tight_layout()
  plt.show()

# %% [markdown]
# Let's see the training run. Validation accuracy is still increasing a bit, so we'll end up training some more

# %%
show_training_curves(history)

# %% [markdown]
# Because the model seems to be learning still, add 10 more epochs. If you *don't recompile*, then the model starts up where it left off. We do have to manually merge the two histories.

# %%
new_history = model.fit(
    ds_train,
    epochs=10,
    validation_data=ds_test,
)

for key in new_history.history:
    history.history[key].extend(new_history.history[key])
# Out:
# Epoch 1/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3860 - sparse_categorical_accuracy: 0.5129 - val_loss: 1.4761 - val_sparse_categorical_accuracy: 0.4764
# Epoch 2/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3742 - sparse_categorical_accuracy: 0.5175 - val_loss: 1.4538 - val_sparse_categorical_accuracy: 0.4844
# Epoch 3/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3711 - sparse_categorical_accuracy: 0.5193 - val_loss: 1.4871 - val_sparse_categorical_accuracy: 0.4713
# Epoch 4/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.3720 - sparse_categorical_accuracy: 0.5177 - val_loss: 1.4725 - val_sparse_categorical_accuracy: 0.4777
# Epoch 5/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3539 - sparse_categorical_accuracy: 0.5246 - val_loss: 1.4876 - val_sparse_categorical_accuracy: 0.4695
# Epoch 6/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3448 - sparse_categorical_accuracy: 0.5301 - val_loss: 1.4581 - val_sparse_categorical_accuracy: 0.4865
# Epoch 7/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3510 - sparse_categorical_accuracy: 0.5260 - val_loss: 1.4690 - val_sparse_categorical_accuracy: 0.4764
# Epoch 8/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3504 - sparse_categorical_accuracy: 0.5262 - val_loss: 1.4634 - val_sparse_categorical_accuracy: 0.4760
# Epoch 9/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3226 - sparse_categorical_accuracy: 0.5390 - val_loss: 1.4604 - val_sparse_categorical_accuracy: 0.4782
# Epoch 10/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3274 - sparse_categorical_accuracy: 0.5367 - val_loss: 1.4714 - val_sparse_categorical_accuracy: 0.4769

# %%
show_training_curves(history)

# %% [markdown]
# Let's create a confusion matrix plotting function and run it. Pay attention to the "predictions" logic!!

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def show_confusion_matrix(model, dataset, info):
  # Get true labels from dataset
  true_labels = []
  for images, labels in dataset.unbatch():
      true_labels.append(labels.numpy())
  true_labels = np.array(true_labels)

  # Predict probabilities for the test set
  predictions = model.predict(dataset)

  # Get predicted classes
  predicted_labels = np.argmax(predictions, axis=1) ## VERY IMPORTANT. How you get a class label out of a neural network.

  # Generate the confusion matrix
  cm = confusion_matrix(true_labels, predicted_labels)

  # Get class names from dataset info (assuming cifar10 has 'label' feature with names)
  class_names = info.features['label'].names

  # Plot the confusion matrix
  plt.figure(figsize=(10, 8))
  sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=class_names, yticklabels=class_names)
  plt.xlabel('Predicted Labels')
  plt.ylabel('True Labels')
  plt.title('Confusion Matrix')
  plt.show()

# %%
show_confusion_matrix(model, ds_test, ds_info)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2026-05-18 23:17:29.685688: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ## Improve

# %% [markdown]
# ### Improving the baseline
# We gradually add **BatchNorm**, **Dropout**, and **L2 regularization** to improve generalization. We also experiment with a smaller learning rate to stabilize training.

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.BatchNormalization(), # Changed to BatchNormalization
  tf.keras.layers.Dense(1024, activation='leaky_relu'),
  tf.keras.layers.Dense(512, activation='leaky_relu'),
  tf.keras.layers.Dense(256, activation='leaky_relu'),
  tf.keras.layers.Dense(10)
])

# No need to call .adapt() for BatchNormalization as it learns stats per batch

model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)


history = model.fit(
    ds_train,
    epochs=30,
    validation_data=ds_test,
)
# Out:
# Epoch 1/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.8856 - sparse_categorical_accuracy: 0.3819 - val_loss: 1.8387 - val_sparse_categorical_accuracy: 0.3970
# Epoch 2/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.4732 - sparse_categorical_accuracy: 0.4833 - val_loss: 1.5795 - val_sparse_categorical_accuracy: 0.4633
# Epoch 3/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.3495 - sparse_categorical_accuracy: 0.5276 - val_loss: 1.4120 - val_sparse_categorical_accuracy: 0.5003
# Epoch 4/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.2563 - sparse_categorical_accuracy: 0.5586 - val_loss: 1.3585 - val_sparse_categorical_accuracy: 0.5151
# Epoch 5/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.1616 - sparse_categorical_accuracy: 0.5925 - val_loss: 1.3764 - val_sparse_categorical_accuracy: 0.5172
# Epoch 6/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.0802 - sparse_categorical_accuracy: 0.6201 - val_loss: 1.3722 - val_sparse_categorical_accuracy: 0.5254
# Epoch 7/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.0018 - sparse_categorical_accuracy: 0.6444 - val_loss: 1.4158 - val_sparse_categorical_accuracy: 0.5269
# Epoch 8/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.9220 - sparse_categorical_accuracy: 0.6746 - val_loss: 1.3929 - val_sparse_categorical_accuracy: 0.5342
# Epoch 9/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.8518 - sparse_categorical_accuracy: 0.6983 - val_loss: 1.4227 - val_sparse_categorical_accuracy: 0.5409
# Epoch 10/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.7811 - sparse_categorical_accuracy: 0.7253 - val_loss: 1.4504 - val_sparse_categorical_accuracy: 0.5384
# Epoch 11/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.7134 - sparse_categorical_accuracy: 0.7508 - val_loss: 1.5178 - val_sparse_categorical_accuracy: 0.5456
# Epoch 12/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.6407 - sparse_categorical_accuracy: 0.7742 - val_loss: 1.5671 - val_sparse_categorical_accuracy: 0.5395
# Epoch 13/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.5992 - sparse_categorical_accuracy: 0.7875 - val_loss: 1.7064 - val_sparse_categorical_accuracy: 0.5272
# Epoch 14/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.5289 - sparse_categorical_accuracy: 0.8149 - val_loss: 1.7326 - val_sparse_categorical_accuracy: 0.5341
# Epoch 15/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.5089 - sparse_categorical_accuracy: 0.8210 - val_loss: 1.8099 - val_sparse_categorical_accuracy: 0.5352
# Epoch 16/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.4342 - sparse_categorical_accuracy: 0.8464 - val_loss: 1.8553 - val_sparse_categorical_accuracy: 0.5355
# Epoch 17/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.4030 - sparse_categorical_accuracy: 0.8583 - val_loss: 1.9480 - val_sparse_categorical_accuracy: 0.5393
# Epoch 18/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.3540 - sparse_categorical_accuracy: 0.8750 - val_loss: 2.0544 - val_sparse_categorical_accuracy: 0.5400
# Epoch 19/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.3454 - sparse_categorical_accuracy: 0.8786 - val_loss: 2.1345 - val_sparse_categorical_accuracy: 0.5371
# Epoch 20/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.3327 - sparse_categorical_accuracy: 0.8837 - val_loss: 2.1304 - val_sparse_categorical_accuracy: 0.5363
# Epoch 21/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.2893 - sparse_categorical_accuracy: 0.8984 - val_loss: 2.2869 - val_sparse_categorical_accuracy: 0.5449
# Epoch 22/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2720 - sparse_categorical_accuracy: 0.9050 - val_loss: 2.3735 - val_sparse_categorical_accuracy: 0.5341
# Epoch 23/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2429 - sparse_categorical_accuracy: 0.9135 - val_loss: 2.4254 - val_sparse_categorical_accuracy: 0.5351
# Epoch 24/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2386 - sparse_categorical_accuracy: 0.9167 - val_loss: 2.5248 - val_sparse_categorical_accuracy: 0.5430
# Epoch 25/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.2625 - sparse_categorical_accuracy: 0.9083 - val_loss: 2.6397 - val_sparse_categorical_accuracy: 0.5305
# Epoch 26/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2420 - sparse_categorical_accuracy: 0.9158 - val_loss: 2.6251 - val_sparse_categorical_accuracy: 0.5366
# Epoch 27/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2351 - sparse_categorical_accuracy: 0.9179 - val_loss: 2.6812 - val_sparse_categorical_accuracy: 0.5393
# Epoch 28/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1811 - sparse_categorical_accuracy: 0.9370 - val_loss: 2.7286 - val_sparse_categorical_accuracy: 0.5398
# Epoch 29/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1692 - sparse_categorical_accuracy: 0.9408 - val_loss: 2.8319 - val_sparse_categorical_accuracy: 0.5369
# Epoch 30/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1642 - sparse_categorical_accuracy: 0.9415 - val_loss: 2.9770 - val_sparse_categorical_accuracy: 0.5416

# %%
show_training_curves(history)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dense(1024, activation='leaky_relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)), # Added L2 regularization
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(512, activation='leaky_relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)), # Added L2 regularization
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(256, activation='leaky_relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])


model.compile(
    optimizer=tf.keras.optimizers.Adam(0.0001),  ## decreased learning rate
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# Define EarlyStopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_sparse_categorical_accuracy',  # Monitor validation accuracy
    mode='max',             # Maximize validation accuracy
    patience=5,          # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True # Restore model weights from the epoch with the best value of the monitored quantity.
)

history = model.fit(
    ds_train,
    epochs=30,
    validation_data=ds_test,
    callbacks=[early_stopping_callback] # Add early stopping callback
)
# Out:
# Epoch 1/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 4.0986 - sparse_categorical_accuracy: 0.3353 - val_loss: 4.0401 - val_sparse_categorical_accuracy: 0.3977
# Epoch 2/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.7736 - sparse_categorical_accuracy: 0.4162 - val_loss: 3.7626 - val_sparse_categorical_accuracy: 0.4550
# Epoch 3/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.6248 - sparse_categorical_accuracy: 0.4432 - val_loss: 3.5483 - val_sparse_categorical_accuracy: 0.4811
# Epoch 4/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.4794 - sparse_categorical_accuracy: 0.4698 - val_loss: 3.3933 - val_sparse_categorical_accuracy: 0.4883
# Epoch 5/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 3.3580 - sparse_categorical_accuracy: 0.4866 - val_loss: 3.2753 - val_sparse_categorical_accuracy: 0.5036
# Epoch 6/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 3.2472 - sparse_categorical_accuracy: 0.5036 - val_loss: 3.1879 - val_sparse_categorical_accuracy: 0.5079
# Epoch 7/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.1452 - sparse_categorical_accuracy: 0.5137 - val_loss: 3.0962 - val_sparse_categorical_accuracy: 0.5195
# Epoch 8/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.0420 - sparse_categorical_accuracy: 0.5273 - val_loss: 3.0155 - val_sparse_categorical_accuracy: 0.5252
# Epoch 9/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2.9544 - sparse_categorical_accuracy: 0.5375 - val_loss: 2.9453 - val_sparse_categorical_accuracy: 0.5283
# Epoch 10/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.8629 - sparse_categorical_accuracy: 0.5479 - val_loss: 2.8664 - val_sparse_categorical_accuracy: 0.5334
# Epoch 11/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.7846 - sparse_categorical_accuracy: 0.5539 - val_loss: 2.8041 - val_sparse_categorical_accuracy: 0.5366
# Epoch 12/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 2.6983 - sparse_categorical_accuracy: 0.5669 - val_loss: 2.7388 - val_sparse_categorical_accuracy: 0.5376
# Epoch 13/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.6240 - sparse_categorical_accuracy: 0.5742 - val_loss: 2.6868 - val_sparse_categorical_accuracy: 0.5447
# Epoch 14/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.5553 - sparse_categorical_accuracy: 0.5814 - val_loss: 2.6161 - val_sparse_categorical_accuracy: 0.5470
# Epoch 15/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.4856 - sparse_categorical_accuracy: 0.5873 - val_loss: 2.5687 - val_sparse_categorical_accuracy: 0.5543
# Epoch 16/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.4189 - sparse_categorical_accuracy: 0.5982 - val_loss: 2.5255 - val_sparse_categorical_accuracy: 0.5549
# Epoch 17/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.3554 - sparse_categorical_accuracy: 0.6053 - val_loss: 2.4777 - val_sparse_categorical_accuracy: 0.5530
# Epoch 18/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.3043 - sparse_categorical_accuracy: 0.6113 - val_loss: 2.4378 - val_sparse_categorical_accuracy: 0.5533
# Epoch 19/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.2432 - sparse_categorical_accuracy: 0.6175 - val_loss: 2.3990 - val_sparse_categorical_accuracy: 0.5598
# Epoch 20/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.1895 - sparse_categorical_accuracy: 0.6243 - val_loss: 2.3605 - val_sparse_categorical_accuracy: 0.5574
# Epoch 21/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.1387 - sparse_categorical_accuracy: 0.6316 - val_loss: 2.3114 - val_sparse_categorical_accuracy: 0.5666
# Epoch 22/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.0920 - sparse_categorical_accuracy: 0.6365 - val_loss: 2.3048 - val_sparse_categorical_accuracy: 0.5552
# Epoch 23/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.0422 - sparse_categorical_accuracy: 0.6429 - val_loss: 2.2661 - val_sparse_categorical_accuracy: 0.5587
# Epoch 24/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.0007 - sparse_categorical_accuracy: 0.6475 - val_loss: 2.2261 - val_sparse_categorical_accuracy: 0.5628
# Epoch 25/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.9607 - sparse_categorical_accuracy: 0.6516 - val_loss: 2.2104 - val_sparse_categorical_accuracy: 0.5602
# Epoch 26/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.9155 - sparse_categorical_accuracy: 0.6599 - val_loss: 2.1719 - val_sparse_categorical_accuracy: 0.5664

# %%
show_training_curves(history)

# %%
import tensorflow as tf

def augment_img(image, label):
  # Random horizontal flip
  image = tf.image.random_flip_left_right(image)
  # Random brightness adjustment
  image = tf.image.random_brightness(image, max_delta=0.2)
  # Random contrast adjustment
  image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
  # Random crop by padding and then cropping
  IMG_SIZE = 32
  paddings = tf.constant([[4, 4], [4, 4], [0, 0]]) # Pad by 4 pixels on each side (total 40x40)
  image = tf.pad(image, paddings, "REFLECT") # Use REFLECT padding to avoid black borders
  image = tf.image.random_crop(image, size=[IMG_SIZE, IMG_SIZE, 3])
  return image, label

# Re-build the training pipeline with data augmentation.
# Assumes 'ods_train', 'normalize_img', 'ds_info.splits['train'].num_examples', and 'tf.data.AUTOTUNE' are defined in prior cells.
ds_train = ods_train.map(
    normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.cache()
# Apply data augmentation to the training dataset after caching normalized data
ds_train = ds_train.map(
    augment_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples)
ds_train = ds_train.batch(512)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

print("Training dataset pipeline rebuilt with data augmentation.")
print("The new pipeline includes random horizontal flips, brightness, contrast adjustments, and random cropping.")
# Out:
# Training dataset pipeline rebuilt with data augmentation.
# The new pipeline includes random horizontal flips, brightness, contrast adjustments, and random cropping.

# %% [markdown]
# ### Early stopping and learning-rate tuning
# Early stopping halts training when validation accuracy stops improving, which prevents overfitting and saves time. The lower learning rate here ($10^{-4}$) makes updates smaller and can improve stability.

# %% [markdown]
# ### Checkpoints (recommended)
# Use `ModelCheckpoint` to save the best model during training. Add it to the `callbacks` list alongside early stopping.
#
# Example:
# ```python
# checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
#     filepath='checkpoints/cifar10_ffn.keras',
#     monitor='val_sparse_categorical_accuracy',
#     save_best_only=True,
#     mode='max'
#  )
# history = model.fit(..., callbacks=[early_stopping_callback, checkpoint_cb])
# ```

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dense(1024, activation='leaky_relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(512, activation='leaky_relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(256, activation='leaky_relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])


model.compile(
    optimizer=tf.keras.optimizers.Adam(0.0001),  ## decreased learning rate
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# Define EarlyStopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',  # Monitor validation accuracy
    mode='max',             # Maximize validation accuracy
    patience=5,          # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True # Restore model weights from the epoch with the best value of the monitored quantity.
)

history = model.fit(
    ds_train,
    epochs=30,
    validation_data=ds_test,
    callbacks=[early_stopping_callback] # Add early stopping callback
)
# Out:
# Epoch 1/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 2.0452 - sparse_categorical_accuracy: 0.2787 - val_loss: 1.9272 - val_sparse_categorical_accuracy: 0.3781
# Epoch 2/30
# /Users/pewhite/miniconda3/envs/tfmetal-pip/lib/python3.11/site-packages/keras/src/callbacks/early_stopping.py:99: UserWarning: Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
#   current = self.get_monitor_value(logs)
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.8505 - sparse_categorical_accuracy: 0.3400 - val_loss: 1.7539 - val_sparse_categorical_accuracy: 0.4346
# Epoch 3/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.7886 - sparse_categorical_accuracy: 0.3602 - val_loss: 1.6366 - val_sparse_categorical_accuracy: 0.4527
# Epoch 4/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.7478 - sparse_categorical_accuracy: 0.3780 - val_loss: 1.5658 - val_sparse_categorical_accuracy: 0.4688
# Epoch 5/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.7126 - sparse_categorical_accuracy: 0.3920 - val_loss: 1.5209 - val_sparse_categorical_accuracy: 0.4743
# Epoch 6/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.6938 - sparse_categorical_accuracy: 0.3995 - val_loss: 1.5024 - val_sparse_categorical_accuracy: 0.4802
# Epoch 7/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.6731 - sparse_categorical_accuracy: 0.4045 - val_loss: 1.4700 - val_sparse_categorical_accuracy: 0.4906
# Epoch 8/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.6499 - sparse_categorical_accuracy: 0.4121 - val_loss: 1.4678 - val_sparse_categorical_accuracy: 0.4972
# Epoch 9/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.6364 - sparse_categorical_accuracy: 0.4199 - val_loss: 1.4417 - val_sparse_categorical_accuracy: 0.5010
# Epoch 10/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.6208 - sparse_categorical_accuracy: 0.4248 - val_loss: 1.4257 - val_sparse_categorical_accuracy: 0.5078
# Epoch 11/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.6122 - sparse_categorical_accuracy: 0.4256 - val_loss: 1.4179 - val_sparse_categorical_accuracy: 0.5054
# Epoch 12/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.5990 - sparse_categorical_accuracy: 0.4304 - val_loss: 1.4018 - val_sparse_categorical_accuracy: 0.5122
# Epoch 13/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.5877 - sparse_categorical_accuracy: 0.4362 - val_loss: 1.3981 - val_sparse_categorical_accuracy: 0.5120
# Epoch 14/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.5772 - sparse_categorical_accuracy: 0.4392 - val_loss: 1.3858 - val_sparse_categorical_accuracy: 0.5189
# Epoch 15/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.5684 - sparse_categorical_accuracy: 0.4425 - val_loss: 1.3764 - val_sparse_categorical_accuracy: 0.5165
# Epoch 16/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.5589 - sparse_categorical_accuracy: 0.4478 - val_loss: 1.3746 - val_sparse_categorical_accuracy: 0.5219
# Epoch 17/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.5497 - sparse_categorical_accuracy: 0.4465 - val_loss: 1.3630 - val_sparse_categorical_accuracy: 0.5207
# Epoch 18/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.5428 - sparse_categorical_accuracy: 0.4530 - val_loss: 1.3501 - val_sparse_categorical_accuracy: 0.5327
# Epoch 19/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.5374 - sparse_categorical_accuracy: 0.4542 - val_loss: 1.3463 - val_sparse_categorical_accuracy: 0.5302
# Epoch 20/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 1.5234 - sparse_categorical_accuracy: 0.4575 - val_loss: 1.3344 - val_sparse_categorical_accuracy: 0.5335
# Epoch 21/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.5190 - sparse_categorical_accuracy: 0.4582 - val_loss: 1.3298 - val_sparse_categorical_accuracy: 0.5349
# Epoch 22/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.5073 - sparse_categorical_accuracy: 0.4643 - val_loss: 1.3212 - val_sparse_categorical_accuracy: 0.5370
# Epoch 23/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.5065 - sparse_categorical_accuracy: 0.4672 - val_loss: 1.3183 - val_sparse_categorical_accuracy: 0.5348
# Epoch 24/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.5008 - sparse_categorical_accuracy: 0.4666 - val_loss: 1.3152 - val_sparse_categorical_accuracy: 0.5427
# Epoch 25/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4938 - sparse_categorical_accuracy: 0.4694 - val_loss: 1.3023 - val_sparse_categorical_accuracy: 0.5455
# Epoch 26/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4888 - sparse_categorical_accuracy: 0.4664 - val_loss: 1.2949 - val_sparse_categorical_accuracy: 0.5461
# Epoch 27/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4868 - sparse_categorical_accuracy: 0.4697 - val_loss: 1.2925 - val_sparse_categorical_accuracy: 0.5480
# Epoch 28/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4745 - sparse_categorical_accuracy: 0.4743 - val_loss: 1.2849 - val_sparse_categorical_accuracy: 0.5493
# Epoch 29/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4703 - sparse_categorical_accuracy: 0.4755 - val_loss: 1.2840 - val_sparse_categorical_accuracy: 0.5503
# Epoch 30/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4714 - sparse_categorical_accuracy: 0.4776 - val_loss: 1.2752 - val_sparse_categorical_accuracy: 0.5532

# %%
show_training_curves(history)

# %% [markdown]
# ### Data augmentation
# Augmentation makes the model more robust by creating varied training examples. We apply flips, brightness/contrast changes, and random crops **after** caching normalized images.

# %% [markdown]
# After rebuilding the pipeline, recompile and retrain the model so it learns from the augmented data. Compare the new learning curves to the earlier baseline.

# %%
more_history = model.fit(
    ds_train,
    epochs=30,
    validation_data=ds_test,
    callbacks=[early_stopping_callback] # Add early stopping callback
)
# Out:
# Epoch 1/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 1.4519 - sparse_categorical_accuracy: 0.4822 - val_loss: 1.2766 - val_sparse_categorical_accuracy: 0.5498
# Epoch 2/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 1.4568 - sparse_categorical_accuracy: 0.4807 - val_loss: 1.2729 - val_sparse_categorical_accuracy: 0.5598
# Epoch 3/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4492 - sparse_categorical_accuracy: 0.4831 - val_loss: 1.2654 - val_sparse_categorical_accuracy: 0.5606
# Epoch 4/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4401 - sparse_categorical_accuracy: 0.4846 - val_loss: 1.2624 - val_sparse_categorical_accuracy: 0.5601
# Epoch 5/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4434 - sparse_categorical_accuracy: 0.4855 - val_loss: 1.2661 - val_sparse_categorical_accuracy: 0.5586
# Epoch 6/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4357 - sparse_categorical_accuracy: 0.4827 - val_loss: 1.2536 - val_sparse_categorical_accuracy: 0.5613
# Epoch 7/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4338 - sparse_categorical_accuracy: 0.4890 - val_loss: 1.2580 - val_sparse_categorical_accuracy: 0.5580
# Epoch 8/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4311 - sparse_categorical_accuracy: 0.4876 - val_loss: 1.2427 - val_sparse_categorical_accuracy: 0.5647
# Epoch 9/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4234 - sparse_categorical_accuracy: 0.4918 - val_loss: 1.2429 - val_sparse_categorical_accuracy: 0.5654
# Epoch 10/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4144 - sparse_categorical_accuracy: 0.4927 - val_loss: 1.2367 - val_sparse_categorical_accuracy: 0.5670
# Epoch 11/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4107 - sparse_categorical_accuracy: 0.4965 - val_loss: 1.2348 - val_sparse_categorical_accuracy: 0.5668
# Epoch 12/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4157 - sparse_categorical_accuracy: 0.4949 - val_loss: 1.2347 - val_sparse_categorical_accuracy: 0.5694
# Epoch 13/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.4069 - sparse_categorical_accuracy: 0.4988 - val_loss: 1.2371 - val_sparse_categorical_accuracy: 0.5653
# Epoch 14/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.4083 - sparse_categorical_accuracy: 0.4952 - val_loss: 1.2250 - val_sparse_categorical_accuracy: 0.5719
# Epoch 15/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.4025 - sparse_categorical_accuracy: 0.5000 - val_loss: 1.2203 - val_sparse_categorical_accuracy: 0.5718
# Epoch 16/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.4016 - sparse_categorical_accuracy: 0.4996 - val_loss: 1.2199 - val_sparse_categorical_accuracy: 0.5701
# Epoch 17/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.3943 - sparse_categorical_accuracy: 0.5018 - val_loss: 1.2137 - val_sparse_categorical_accuracy: 0.5695
# Epoch 18/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.3868 - sparse_categorical_accuracy: 0.5050 - val_loss: 1.2243 - val_sparse_categorical_accuracy: 0.5692
# Epoch 19/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3865 - sparse_categorical_accuracy: 0.5047 - val_loss: 1.2077 - val_sparse_categorical_accuracy: 0.5706
# Epoch 20/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3852 - sparse_categorical_accuracy: 0.5059 - val_loss: 1.2055 - val_sparse_categorical_accuracy: 0.5705
# Epoch 21/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3821 - sparse_categorical_accuracy: 0.5064 - val_loss: 1.2114 - val_sparse_categorical_accuracy: 0.5736
# Epoch 22/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.3769 - sparse_categorical_accuracy: 0.5071 - val_loss: 1.2028 - val_sparse_categorical_accuracy: 0.5762
# Epoch 23/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3776 - sparse_categorical_accuracy: 0.5104 - val_loss: 1.2038 - val_sparse_categorical_accuracy: 0.5751
# Epoch 24/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3748 - sparse_categorical_accuracy: 0.5080 - val_loss: 1.1946 - val_sparse_categorical_accuracy: 0.5783
# Epoch 25/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3728 - sparse_categorical_accuracy: 0.5082 - val_loss: 1.2009 - val_sparse_categorical_accuracy: 0.5773
# Epoch 26/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.3706 - sparse_categorical_accuracy: 0.5078 - val_loss: 1.2049 - val_sparse_categorical_accuracy: 0.5780
# Epoch 27/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3651 - sparse_categorical_accuracy: 0.5097 - val_loss: 1.1909 - val_sparse_categorical_accuracy: 0.5755
# Epoch 28/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3627 - sparse_categorical_accuracy: 0.5110 - val_loss: 1.1946 - val_sparse_categorical_accuracy: 0.5773
# Epoch 29/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3612 - sparse_categorical_accuracy: 0.5128 - val_loss: 1.1836 - val_sparse_categorical_accuracy: 0.5789
# Epoch 30/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3549 - sparse_categorical_accuracy: 0.5164 - val_loss: 1.1851 - val_sparse_categorical_accuracy: 0.5804

# %%
for key in more_history.history:
    history.history[key].extend(more_history.history[key])

# %%
show_training_curves(history)

# %%
more_history = model.fit(
    ds_train,
    epochs=200,
    validation_data=ds_test,
    callbacks=[early_stopping_callback] # Add early stopping callback
)
# Out:
# Epoch 1/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3609 - sparse_categorical_accuracy: 0.5126 - val_loss: 1.1797 - val_sparse_categorical_accuracy: 0.5795
# Epoch 2/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3534 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.1805 - val_sparse_categorical_accuracy: 0.5819
# Epoch 3/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.3510 - sparse_categorical_accuracy: 0.5168 - val_loss: 1.1775 - val_sparse_categorical_accuracy: 0.5820
# Epoch 4/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.3499 - sparse_categorical_accuracy: 0.5180 - val_loss: 1.1808 - val_sparse_categorical_accuracy: 0.5804
# Epoch 5/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.3426 - sparse_categorical_accuracy: 0.5186 - val_loss: 1.1680 - val_sparse_categorical_accuracy: 0.5887
# Epoch 6/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.3446 - sparse_categorical_accuracy: 0.5217 - val_loss: 1.1812 - val_sparse_categorical_accuracy: 0.5794
# Epoch 7/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3400 - sparse_categorical_accuracy: 0.5225 - val_loss: 1.1734 - val_sparse_categorical_accuracy: 0.5874
# Epoch 8/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.3369 - sparse_categorical_accuracy: 0.5201 - val_loss: 1.1723 - val_sparse_categorical_accuracy: 0.5834
# Epoch 9/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3363 - sparse_categorical_accuracy: 0.5225 - val_loss: 1.1729 - val_sparse_categorical_accuracy: 0.5846
# Epoch 10/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3308 - sparse_categorical_accuracy: 0.5237 - val_loss: 1.1732 - val_sparse_categorical_accuracy: 0.5845
# Epoch 11/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.3304 - sparse_categorical_accuracy: 0.5248 - val_loss: 1.1714 - val_sparse_categorical_accuracy: 0.5855
# Epoch 12/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3336 - sparse_categorical_accuracy: 0.5240 - val_loss: 1.1647 - val_sparse_categorical_accuracy: 0.5841
# Epoch 13/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3348 - sparse_categorical_accuracy: 0.5238 - val_loss: 1.1544 - val_sparse_categorical_accuracy: 0.5902
# Epoch 14/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3263 - sparse_categorical_accuracy: 0.5267 - val_loss: 1.1561 - val_sparse_categorical_accuracy: 0.5910
# Epoch 15/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3250 - sparse_categorical_accuracy: 0.5279 - val_loss: 1.1540 - val_sparse_categorical_accuracy: 0.5926
# Epoch 16/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3264 - sparse_categorical_accuracy: 0.5272 - val_loss: 1.1529 - val_sparse_categorical_accuracy: 0.5898
# Epoch 17/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3196 - sparse_categorical_accuracy: 0.5266 - val_loss: 1.1530 - val_sparse_categorical_accuracy: 0.5888
# Epoch 18/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3134 - sparse_categorical_accuracy: 0.5306 - val_loss: 1.1520 - val_sparse_categorical_accuracy: 0.5899
# Epoch 19/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3172 - sparse_categorical_accuracy: 0.5294 - val_loss: 1.1551 - val_sparse_categorical_accuracy: 0.5857
# Epoch 20/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3136 - sparse_categorical_accuracy: 0.5313 - val_loss: 1.1481 - val_sparse_categorical_accuracy: 0.5901
# Epoch 21/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.3110 - sparse_categorical_accuracy: 0.5303 - val_loss: 1.1518 - val_sparse_categorical_accuracy: 0.5915
# Epoch 22/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3077 - sparse_categorical_accuracy: 0.5321 - val_loss: 1.1504 - val_sparse_categorical_accuracy: 0.5919
# Epoch 23/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3099 - sparse_categorical_accuracy: 0.5327 - val_loss: 1.1500 - val_sparse_categorical_accuracy: 0.5886
# Epoch 24/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3072 - sparse_categorical_accuracy: 0.5330 - val_loss: 1.1383 - val_sparse_categorical_accuracy: 0.5992
# Epoch 25/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3063 - sparse_categorical_accuracy: 0.5318 - val_loss: 1.1498 - val_sparse_categorical_accuracy: 0.5933
# Epoch 26/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3053 - sparse_categorical_accuracy: 0.5350 - val_loss: 1.1398 - val_sparse_categorical_accuracy: 0.5930
# Epoch 27/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3009 - sparse_categorical_accuracy: 0.5332 - val_loss: 1.1364 - val_sparse_categorical_accuracy: 0.5955
# Epoch 28/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3012 - sparse_categorical_accuracy: 0.5371 - val_loss: 1.1375 - val_sparse_categorical_accuracy: 0.5966
# Epoch 29/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.2927 - sparse_categorical_accuracy: 0.5383 - val_loss: 1.1340 - val_sparse_categorical_accuracy: 0.5961
# Epoch 30/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.3030 - sparse_categorical_accuracy: 0.5352 - val_loss: 1.1343 - val_sparse_categorical_accuracy: 0.5970
# Epoch 31/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.2951 - sparse_categorical_accuracy: 0.5409 - val_loss: 1.1326 - val_sparse_categorical_accuracy: 0.5945
# Epoch 32/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2873 - sparse_categorical_accuracy: 0.5405 - val_loss: 1.1292 - val_sparse_categorical_accuracy: 0.5958
# Epoch 33/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2913 - sparse_categorical_accuracy: 0.5384 - val_loss: 1.1308 - val_sparse_categorical_accuracy: 0.5945
# Epoch 34/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2884 - sparse_categorical_accuracy: 0.5398 - val_loss: 1.1343 - val_sparse_categorical_accuracy: 0.5982
# Epoch 35/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.2907 - sparse_categorical_accuracy: 0.5391 - val_loss: 1.1290 - val_sparse_categorical_accuracy: 0.5983
# Epoch 36/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.2854 - sparse_categorical_accuracy: 0.5392 - val_loss: 1.1325 - val_sparse_categorical_accuracy: 0.5948
# Epoch 37/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.2841 - sparse_categorical_accuracy: 0.5426 - val_loss: 1.1249 - val_sparse_categorical_accuracy: 0.6035
# Epoch 38/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.2833 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.1269 - val_sparse_categorical_accuracy: 0.6025
# Epoch 39/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.2847 - sparse_categorical_accuracy: 0.5419 - val_loss: 1.1280 - val_sparse_categorical_accuracy: 0.6010
# Epoch 40/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.2823 - sparse_categorical_accuracy: 0.5420 - val_loss: 1.1228 - val_sparse_categorical_accuracy: 0.6033
# Epoch 41/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.2816 - sparse_categorical_accuracy: 0.5428 - val_loss: 1.1257 - val_sparse_categorical_accuracy: 0.6032
# Epoch 42/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.2821 - sparse_categorical_accuracy: 0.5421 - val_loss: 1.1211 - val_sparse_categorical_accuracy: 0.6031
# Epoch 43/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2762 - sparse_categorical_accuracy: 0.5478 - val_loss: 1.1169 - val_sparse_categorical_accuracy: 0.6005
# Epoch 44/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.2760 - sparse_categorical_accuracy: 0.5443 - val_loss: 1.1203 - val_sparse_categorical_accuracy: 0.6023
# Epoch 45/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.2690 - sparse_categorical_accuracy: 0.5473 - val_loss: 1.1177 - val_sparse_categorical_accuracy: 0.6041
# Epoch 46/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.2754 - sparse_categorical_accuracy: 0.5433 - val_loss: 1.1137 - val_sparse_categorical_accuracy: 0.6041
# Epoch 47/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.2746 - sparse_categorical_accuracy: 0.5449 - val_loss: 1.1149 - val_sparse_categorical_accuracy: 0.6013
# Epoch 48/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.2703 - sparse_categorical_accuracy: 0.5473 - val_loss: 1.1200 - val_sparse_categorical_accuracy: 0.6002
# Epoch 49/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2689 - sparse_categorical_accuracy: 0.5493 - val_loss: 1.1127 - val_sparse_categorical_accuracy: 0.6039
# Epoch 50/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2709 - sparse_categorical_accuracy: 0.5470 - val_loss: 1.1102 - val_sparse_categorical_accuracy: 0.6064
# Epoch 51/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2601 - sparse_categorical_accuracy: 0.5511 - val_loss: 1.1032 - val_sparse_categorical_accuracy: 0.6084
# Epoch 52/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2627 - sparse_categorical_accuracy: 0.5502 - val_loss: 1.1071 - val_sparse_categorical_accuracy: 0.6103
# Epoch 53/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2649 - sparse_categorical_accuracy: 0.5502 - val_loss: 1.1017 - val_sparse_categorical_accuracy: 0.6112
# Epoch 54/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2564 - sparse_categorical_accuracy: 0.5531 - val_loss: 1.1013 - val_sparse_categorical_accuracy: 0.6059
# Epoch 55/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2584 - sparse_categorical_accuracy: 0.5538 - val_loss: 1.1029 - val_sparse_categorical_accuracy: 0.6111
# Epoch 56/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2620 - sparse_categorical_accuracy: 0.5505 - val_loss: 1.0993 - val_sparse_categorical_accuracy: 0.6089
# Epoch 57/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 1.2614 - sparse_categorical_accuracy: 0.5508 - val_loss: 1.0993 - val_sparse_categorical_accuracy: 0.6063
# Epoch 58/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2531 - sparse_categorical_accuracy: 0.5523 - val_loss: 1.0985 - val_sparse_categorical_accuracy: 0.6073
# Epoch 59/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2556 - sparse_categorical_accuracy: 0.5517 - val_loss: 1.1096 - val_sparse_categorical_accuracy: 0.6059
# Epoch 60/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2540 - sparse_categorical_accuracy: 0.5531 - val_loss: 1.0976 - val_sparse_categorical_accuracy: 0.6067
# Epoch 61/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2510 - sparse_categorical_accuracy: 0.5555 - val_loss: 1.0921 - val_sparse_categorical_accuracy: 0.6102
# Epoch 62/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.2518 - sparse_categorical_accuracy: 0.5511 - val_loss: 1.0906 - val_sparse_categorical_accuracy: 0.6077
# Epoch 63/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2475 - sparse_categorical_accuracy: 0.5545 - val_loss: 1.0957 - val_sparse_categorical_accuracy: 0.6110
# Epoch 64/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2425 - sparse_categorical_accuracy: 0.5572 - val_loss: 1.0880 - val_sparse_categorical_accuracy: 0.6118
# Epoch 65/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2486 - sparse_categorical_accuracy: 0.5534 - val_loss: 1.0910 - val_sparse_categorical_accuracy: 0.6094
# Epoch 66/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2473 - sparse_categorical_accuracy: 0.5547 - val_loss: 1.0907 - val_sparse_categorical_accuracy: 0.6105
# Epoch 67/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2374 - sparse_categorical_accuracy: 0.5589 - val_loss: 1.0919 - val_sparse_categorical_accuracy: 0.6115
# Epoch 68/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2366 - sparse_categorical_accuracy: 0.5576 - val_loss: 1.0881 - val_sparse_categorical_accuracy: 0.6136
# Epoch 69/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2379 - sparse_categorical_accuracy: 0.5593 - val_loss: 1.0946 - val_sparse_categorical_accuracy: 0.6080
# Epoch 70/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2424 - sparse_categorical_accuracy: 0.5550 - val_loss: 1.0929 - val_sparse_categorical_accuracy: 0.6130
# Epoch 71/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.2332 - sparse_categorical_accuracy: 0.5621 - val_loss: 1.0863 - val_sparse_categorical_accuracy: 0.6141
# Epoch 72/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2353 - sparse_categorical_accuracy: 0.5571 - val_loss: 1.0864 - val_sparse_categorical_accuracy: 0.6144
# Epoch 73/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.2379 - sparse_categorical_accuracy: 0.5583 - val_loss: 1.0796 - val_sparse_categorical_accuracy: 0.6179
# Epoch 74/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2352 - sparse_categorical_accuracy: 0.5583 - val_loss: 1.0817 - val_sparse_categorical_accuracy: 0.6181
# Epoch 75/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2343 - sparse_categorical_accuracy: 0.5570 - val_loss: 1.0831 - val_sparse_categorical_accuracy: 0.6133
# Epoch 76/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2302 - sparse_categorical_accuracy: 0.5626 - val_loss: 1.0794 - val_sparse_categorical_accuracy: 0.6123
# Epoch 77/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2291 - sparse_categorical_accuracy: 0.5618 - val_loss: 1.0764 - val_sparse_categorical_accuracy: 0.6134
# Epoch 78/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.2341 - sparse_categorical_accuracy: 0.5594 - val_loss: 1.0750 - val_sparse_categorical_accuracy: 0.6206
# Epoch 79/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2250 - sparse_categorical_accuracy: 0.5616 - val_loss: 1.0731 - val_sparse_categorical_accuracy: 0.6227
# Epoch 80/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2298 - sparse_categorical_accuracy: 0.5609 - val_loss: 1.0777 - val_sparse_categorical_accuracy: 0.6156
# Epoch 81/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2319 - sparse_categorical_accuracy: 0.5597 - val_loss: 1.0749 - val_sparse_categorical_accuracy: 0.6194
# Epoch 82/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2284 - sparse_categorical_accuracy: 0.5596 - val_loss: 1.0803 - val_sparse_categorical_accuracy: 0.6146
# Epoch 83/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2314 - sparse_categorical_accuracy: 0.5608 - val_loss: 1.0759 - val_sparse_categorical_accuracy: 0.6158
# Epoch 84/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2176 - sparse_categorical_accuracy: 0.5664 - val_loss: 1.0740 - val_sparse_categorical_accuracy: 0.6166
# Epoch 85/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2216 - sparse_categorical_accuracy: 0.5650 - val_loss: 1.0691 - val_sparse_categorical_accuracy: 0.6161
# Epoch 86/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2191 - sparse_categorical_accuracy: 0.5673 - val_loss: 1.0712 - val_sparse_categorical_accuracy: 0.6180
# Epoch 87/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2243 - sparse_categorical_accuracy: 0.5642 - val_loss: 1.0747 - val_sparse_categorical_accuracy: 0.6181
# Epoch 88/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2178 - sparse_categorical_accuracy: 0.5640 - val_loss: 1.0736 - val_sparse_categorical_accuracy: 0.6194
# Epoch 89/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2172 - sparse_categorical_accuracy: 0.5648 - val_loss: 1.0690 - val_sparse_categorical_accuracy: 0.6164
# Epoch 90/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2214 - sparse_categorical_accuracy: 0.5629 - val_loss: 1.0666 - val_sparse_categorical_accuracy: 0.6141
# Epoch 91/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2149 - sparse_categorical_accuracy: 0.5672 - val_loss: 1.0686 - val_sparse_categorical_accuracy: 0.6202
# Epoch 92/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2161 - sparse_categorical_accuracy: 0.5641 - val_loss: 1.0573 - val_sparse_categorical_accuracy: 0.6206
# Epoch 93/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2181 - sparse_categorical_accuracy: 0.5667 - val_loss: 1.0645 - val_sparse_categorical_accuracy: 0.6207
# Epoch 94/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2100 - sparse_categorical_accuracy: 0.5698 - val_loss: 1.0662 - val_sparse_categorical_accuracy: 0.6217
# Epoch 95/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2119 - sparse_categorical_accuracy: 0.5657 - val_loss: 1.0562 - val_sparse_categorical_accuracy: 0.6221
# Epoch 96/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2107 - sparse_categorical_accuracy: 0.5684 - val_loss: 1.0698 - val_sparse_categorical_accuracy: 0.6204
# Epoch 97/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2121 - sparse_categorical_accuracy: 0.5680 - val_loss: 1.0527 - val_sparse_categorical_accuracy: 0.6260
# Epoch 98/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2100 - sparse_categorical_accuracy: 0.5676 - val_loss: 1.0533 - val_sparse_categorical_accuracy: 0.6257
# Epoch 99/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2078 - sparse_categorical_accuracy: 0.5681 - val_loss: 1.0573 - val_sparse_categorical_accuracy: 0.6230
# Epoch 100/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2075 - sparse_categorical_accuracy: 0.5717 - val_loss: 1.0575 - val_sparse_categorical_accuracy: 0.6229
# Epoch 101/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2052 - sparse_categorical_accuracy: 0.5701 - val_loss: 1.0606 - val_sparse_categorical_accuracy: 0.6221
# Epoch 102/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2036 - sparse_categorical_accuracy: 0.5737 - val_loss: 1.0575 - val_sparse_categorical_accuracy: 0.6261
# Epoch 103/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2057 - sparse_categorical_accuracy: 0.5693 - val_loss: 1.0507 - val_sparse_categorical_accuracy: 0.6273
# Epoch 104/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.2035 - sparse_categorical_accuracy: 0.5701 - val_loss: 1.0542 - val_sparse_categorical_accuracy: 0.6238
# Epoch 105/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.2065 - sparse_categorical_accuracy: 0.5681 - val_loss: 1.0526 - val_sparse_categorical_accuracy: 0.6264
# Epoch 106/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1988 - sparse_categorical_accuracy: 0.5708 - val_loss: 1.0544 - val_sparse_categorical_accuracy: 0.6251
# Epoch 107/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 1.2008 - sparse_categorical_accuracy: 0.5715 - val_loss: 1.0464 - val_sparse_categorical_accuracy: 0.6284
# Epoch 108/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 1.2018 - sparse_categorical_accuracy: 0.5723 - val_loss: 1.0506 - val_sparse_categorical_accuracy: 0.6243
# Epoch 109/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1955 - sparse_categorical_accuracy: 0.5724 - val_loss: 1.0464 - val_sparse_categorical_accuracy: 0.6262
# Epoch 110/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.1975 - sparse_categorical_accuracy: 0.5718 - val_loss: 1.0441 - val_sparse_categorical_accuracy: 0.6280
# Epoch 111/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1949 - sparse_categorical_accuracy: 0.5722 - val_loss: 1.0489 - val_sparse_categorical_accuracy: 0.6217
# Epoch 112/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1953 - sparse_categorical_accuracy: 0.5723 - val_loss: 1.0449 - val_sparse_categorical_accuracy: 0.6266
# Epoch 113/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1992 - sparse_categorical_accuracy: 0.5740 - val_loss: 1.0556 - val_sparse_categorical_accuracy: 0.6229
# Epoch 114/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1943 - sparse_categorical_accuracy: 0.5737 - val_loss: 1.0471 - val_sparse_categorical_accuracy: 0.6223
# Epoch 115/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1916 - sparse_categorical_accuracy: 0.5747 - val_loss: 1.0476 - val_sparse_categorical_accuracy: 0.6264
# Epoch 116/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1959 - sparse_categorical_accuracy: 0.5753 - val_loss: 1.0446 - val_sparse_categorical_accuracy: 0.6279
# Epoch 117/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1931 - sparse_categorical_accuracy: 0.5738 - val_loss: 1.0377 - val_sparse_categorical_accuracy: 0.6303
# Epoch 118/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1864 - sparse_categorical_accuracy: 0.5780 - val_loss: 1.0445 - val_sparse_categorical_accuracy: 0.6299
# Epoch 119/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1919 - sparse_categorical_accuracy: 0.5756 - val_loss: 1.0487 - val_sparse_categorical_accuracy: 0.6278
# Epoch 120/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1845 - sparse_categorical_accuracy: 0.5770 - val_loss: 1.0385 - val_sparse_categorical_accuracy: 0.6307
# Epoch 121/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1866 - sparse_categorical_accuracy: 0.5757 - val_loss: 1.0325 - val_sparse_categorical_accuracy: 0.6360
# Epoch 122/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1818 - sparse_categorical_accuracy: 0.5784 - val_loss: 1.0370 - val_sparse_categorical_accuracy: 0.6318
# Epoch 123/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1794 - sparse_categorical_accuracy: 0.5787 - val_loss: 1.0472 - val_sparse_categorical_accuracy: 0.6302
# Epoch 124/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1834 - sparse_categorical_accuracy: 0.5771 - val_loss: 1.0397 - val_sparse_categorical_accuracy: 0.6297
# Epoch 125/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1843 - sparse_categorical_accuracy: 0.5783 - val_loss: 1.0363 - val_sparse_categorical_accuracy: 0.6322
# Epoch 126/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1850 - sparse_categorical_accuracy: 0.5777 - val_loss: 1.0426 - val_sparse_categorical_accuracy: 0.6348
# Epoch 127/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1852 - sparse_categorical_accuracy: 0.5784 - val_loss: 1.0436 - val_sparse_categorical_accuracy: 0.6319
# Epoch 128/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1811 - sparse_categorical_accuracy: 0.5782 - val_loss: 1.0368 - val_sparse_categorical_accuracy: 0.6292
# Epoch 129/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1777 - sparse_categorical_accuracy: 0.5795 - val_loss: 1.0347 - val_sparse_categorical_accuracy: 0.6298
# Epoch 130/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1772 - sparse_categorical_accuracy: 0.5844 - val_loss: 1.0307 - val_sparse_categorical_accuracy: 0.6351
# Epoch 131/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1776 - sparse_categorical_accuracy: 0.5791 - val_loss: 1.0277 - val_sparse_categorical_accuracy: 0.6351
# Epoch 132/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1767 - sparse_categorical_accuracy: 0.5802 - val_loss: 1.0293 - val_sparse_categorical_accuracy: 0.6319
# Epoch 133/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1730 - sparse_categorical_accuracy: 0.5794 - val_loss: 1.0370 - val_sparse_categorical_accuracy: 0.6335
# Epoch 134/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1715 - sparse_categorical_accuracy: 0.5820 - val_loss: 1.0303 - val_sparse_categorical_accuracy: 0.6343
# Epoch 135/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1723 - sparse_categorical_accuracy: 0.5824 - val_loss: 1.0249 - val_sparse_categorical_accuracy: 0.6380
# Epoch 136/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1697 - sparse_categorical_accuracy: 0.5839 - val_loss: 1.0337 - val_sparse_categorical_accuracy: 0.6352
# Epoch 137/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1733 - sparse_categorical_accuracy: 0.5819 - val_loss: 1.0329 - val_sparse_categorical_accuracy: 0.6324
# Epoch 138/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1714 - sparse_categorical_accuracy: 0.5821 - val_loss: 1.0303 - val_sparse_categorical_accuracy: 0.6359
# Epoch 139/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1743 - sparse_categorical_accuracy: 0.5818 - val_loss: 1.0296 - val_sparse_categorical_accuracy: 0.6323
# Epoch 140/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1695 - sparse_categorical_accuracy: 0.5823 - val_loss: 1.0252 - val_sparse_categorical_accuracy: 0.6326
# Epoch 141/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1707 - sparse_categorical_accuracy: 0.5842 - val_loss: 1.0327 - val_sparse_categorical_accuracy: 0.6335
# Epoch 142/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1729 - sparse_categorical_accuracy: 0.5836 - val_loss: 1.0240 - val_sparse_categorical_accuracy: 0.6361
# Epoch 143/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1671 - sparse_categorical_accuracy: 0.5852 - val_loss: 1.0269 - val_sparse_categorical_accuracy: 0.6358
# Epoch 144/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1685 - sparse_categorical_accuracy: 0.5821 - val_loss: 1.0228 - val_sparse_categorical_accuracy: 0.6371
# Epoch 145/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1680 - sparse_categorical_accuracy: 0.5825 - val_loss: 1.0221 - val_sparse_categorical_accuracy: 0.6361
# Epoch 146/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.1736 - sparse_categorical_accuracy: 0.5830 - val_loss: 1.0185 - val_sparse_categorical_accuracy: 0.6387
# Epoch 147/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 1.1637 - sparse_categorical_accuracy: 0.5865 - val_loss: 1.0230 - val_sparse_categorical_accuracy: 0.6382
# Epoch 148/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1715 - sparse_categorical_accuracy: 0.5834 - val_loss: 1.0301 - val_sparse_categorical_accuracy: 0.6317
# Epoch 149/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.1654 - sparse_categorical_accuracy: 0.5861 - val_loss: 1.0185 - val_sparse_categorical_accuracy: 0.6373
# Epoch 150/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.1589 - sparse_categorical_accuracy: 0.5868 - val_loss: 1.0192 - val_sparse_categorical_accuracy: 0.6365
# Epoch 151/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1590 - sparse_categorical_accuracy: 0.5882 - val_loss: 1.0261 - val_sparse_categorical_accuracy: 0.6364
# Epoch 152/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1574 - sparse_categorical_accuracy: 0.5896 - val_loss: 1.0196 - val_sparse_categorical_accuracy: 0.6383
# Epoch 153/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1572 - sparse_categorical_accuracy: 0.5875 - val_loss: 1.0195 - val_sparse_categorical_accuracy: 0.6407
# Epoch 154/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1506 - sparse_categorical_accuracy: 0.5888 - val_loss: 1.0195 - val_sparse_categorical_accuracy: 0.6385
# Epoch 155/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1621 - sparse_categorical_accuracy: 0.5865 - val_loss: 1.0175 - val_sparse_categorical_accuracy: 0.6380
# Epoch 156/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1565 - sparse_categorical_accuracy: 0.5865 - val_loss: 1.0178 - val_sparse_categorical_accuracy: 0.6374
# Epoch 157/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1544 - sparse_categorical_accuracy: 0.5874 - val_loss: 1.0176 - val_sparse_categorical_accuracy: 0.6372
# Epoch 158/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1594 - sparse_categorical_accuracy: 0.5863 - val_loss: 1.0149 - val_sparse_categorical_accuracy: 0.6401
# Epoch 159/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1552 - sparse_categorical_accuracy: 0.5895 - val_loss: 1.0210 - val_sparse_categorical_accuracy: 0.6376
# Epoch 160/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1515 - sparse_categorical_accuracy: 0.5894 - val_loss: 1.0108 - val_sparse_categorical_accuracy: 0.6397
# Epoch 161/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1545 - sparse_categorical_accuracy: 0.5857 - val_loss: 1.0145 - val_sparse_categorical_accuracy: 0.6381
# Epoch 162/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1512 - sparse_categorical_accuracy: 0.5898 - val_loss: 1.0069 - val_sparse_categorical_accuracy: 0.6456
# Epoch 163/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1556 - sparse_categorical_accuracy: 0.5877 - val_loss: 1.0128 - val_sparse_categorical_accuracy: 0.6387
# Epoch 164/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1488 - sparse_categorical_accuracy: 0.5917 - val_loss: 1.0044 - val_sparse_categorical_accuracy: 0.6442
# Epoch 165/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1463 - sparse_categorical_accuracy: 0.5901 - val_loss: 1.0100 - val_sparse_categorical_accuracy: 0.6425
# Epoch 166/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1499 - sparse_categorical_accuracy: 0.5898 - val_loss: 1.0078 - val_sparse_categorical_accuracy: 0.6410
# Epoch 167/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1465 - sparse_categorical_accuracy: 0.5914 - val_loss: 1.0059 - val_sparse_categorical_accuracy: 0.6412
# Epoch 168/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1424 - sparse_categorical_accuracy: 0.5937 - val_loss: 1.0037 - val_sparse_categorical_accuracy: 0.6444
# Epoch 169/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1463 - sparse_categorical_accuracy: 0.5923 - val_loss: 1.0030 - val_sparse_categorical_accuracy: 0.6421
# Epoch 170/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1441 - sparse_categorical_accuracy: 0.5909 - val_loss: 1.0018 - val_sparse_categorical_accuracy: 0.6423
# Epoch 171/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1417 - sparse_categorical_accuracy: 0.5935 - val_loss: 1.0039 - val_sparse_categorical_accuracy: 0.6409
# Epoch 172/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1507 - sparse_categorical_accuracy: 0.5924 - val_loss: 1.0056 - val_sparse_categorical_accuracy: 0.6422
# Epoch 173/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1474 - sparse_categorical_accuracy: 0.5906 - val_loss: 1.0059 - val_sparse_categorical_accuracy: 0.6413
# Epoch 174/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1410 - sparse_categorical_accuracy: 0.5955 - val_loss: 0.9996 - val_sparse_categorical_accuracy: 0.6416
# Epoch 175/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1393 - sparse_categorical_accuracy: 0.5946 - val_loss: 1.0041 - val_sparse_categorical_accuracy: 0.6431
# Epoch 176/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1442 - sparse_categorical_accuracy: 0.5940 - val_loss: 1.0090 - val_sparse_categorical_accuracy: 0.6417
# Epoch 177/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1489 - sparse_categorical_accuracy: 0.5916 - val_loss: 1.0064 - val_sparse_categorical_accuracy: 0.6406
# Epoch 178/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1375 - sparse_categorical_accuracy: 0.5944 - val_loss: 1.0011 - val_sparse_categorical_accuracy: 0.6463
# Epoch 179/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1413 - sparse_categorical_accuracy: 0.5932 - val_loss: 0.9997 - val_sparse_categorical_accuracy: 0.6490
# Epoch 180/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1456 - sparse_categorical_accuracy: 0.5941 - val_loss: 1.0033 - val_sparse_categorical_accuracy: 0.6435
# Epoch 181/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1365 - sparse_categorical_accuracy: 0.5935 - val_loss: 1.0018 - val_sparse_categorical_accuracy: 0.6455
# Epoch 182/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 1.1377 - sparse_categorical_accuracy: 0.5964 - val_loss: 1.0058 - val_sparse_categorical_accuracy: 0.6443
# Epoch 183/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1360 - sparse_categorical_accuracy: 0.5979 - val_loss: 0.9991 - val_sparse_categorical_accuracy: 0.6476
# Epoch 184/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1406 - sparse_categorical_accuracy: 0.5954 - val_loss: 0.9922 - val_sparse_categorical_accuracy: 0.6505
# Epoch 185/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1361 - sparse_categorical_accuracy: 0.5968 - val_loss: 0.9944 - val_sparse_categorical_accuracy: 0.6497
# Epoch 186/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1376 - sparse_categorical_accuracy: 0.5945 - val_loss: 0.9985 - val_sparse_categorical_accuracy: 0.6447
# Epoch 187/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1323 - sparse_categorical_accuracy: 0.5977 - val_loss: 0.9918 - val_sparse_categorical_accuracy: 0.6463
# Epoch 188/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1330 - sparse_categorical_accuracy: 0.5965 - val_loss: 0.9961 - val_sparse_categorical_accuracy: 0.6456
# Epoch 189/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 1.1272 - sparse_categorical_accuracy: 0.5992 - val_loss: 0.9923 - val_sparse_categorical_accuracy: 0.6475
# Epoch 190/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1320 - sparse_categorical_accuracy: 0.5989 - val_loss: 0.9977 - val_sparse_categorical_accuracy: 0.6452
# Epoch 191/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1318 - sparse_categorical_accuracy: 0.5956 - val_loss: 1.0011 - val_sparse_categorical_accuracy: 0.6462
# Epoch 192/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1273 - sparse_categorical_accuracy: 0.6011 - val_loss: 0.9960 - val_sparse_categorical_accuracy: 0.6483
# Epoch 193/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1303 - sparse_categorical_accuracy: 0.5969 - val_loss: 0.9966 - val_sparse_categorical_accuracy: 0.6483
# Epoch 194/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1303 - sparse_categorical_accuracy: 0.5971 - val_loss: 0.9927 - val_sparse_categorical_accuracy: 0.6476
# Epoch 195/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1308 - sparse_categorical_accuracy: 0.5970 - val_loss: 0.9996 - val_sparse_categorical_accuracy: 0.6448
# Epoch 196/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1283 - sparse_categorical_accuracy: 0.5976 - val_loss: 0.9960 - val_sparse_categorical_accuracy: 0.6463
# Epoch 197/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.1284 - sparse_categorical_accuracy: 0.5981 - val_loss: 0.9904 - val_sparse_categorical_accuracy: 0.6492
# Epoch 198/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1339 - sparse_categorical_accuracy: 0.5976 - val_loss: 0.9957 - val_sparse_categorical_accuracy: 0.6473
# Epoch 199/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1216 - sparse_categorical_accuracy: 0.6005 - val_loss: 0.9873 - val_sparse_categorical_accuracy: 0.6501
# Epoch 200/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 1.1323 - sparse_categorical_accuracy: 0.5972 - val_loss: 0.9832 - val_sparse_categorical_accuracy: 0.6506

# %%
for key in more_history.history:
    history.history[key].extend(more_history.history[key])

# %%
show_training_curves(history)

# %%
even_more_history = model.fit(
    ds_train,
    epochs=200,
    validation_data=ds_test,
    callbacks=[early_stopping_callback] # Add early stopping callback
)
# Out:
# Epoch 1/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1222 - sparse_categorical_accuracy: 0.5986 - val_loss: 0.9825 - val_sparse_categorical_accuracy: 0.6511
# Epoch 2/200
# /Users/pewhite/miniconda3/envs/tfmetal-pip/lib/python3.11/site-packages/keras/src/callbacks/early_stopping.py:99: UserWarning: Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
#   current = self.get_monitor_value(logs)
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1213 - sparse_categorical_accuracy: 0.5995 - val_loss: 0.9857 - val_sparse_categorical_accuracy: 0.6494
# Epoch 3/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1244 - sparse_categorical_accuracy: 0.6023 - val_loss: 0.9867 - val_sparse_categorical_accuracy: 0.6459
# Epoch 4/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1253 - sparse_categorical_accuracy: 0.5988 - val_loss: 0.9913 - val_sparse_categorical_accuracy: 0.6455
# Epoch 5/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.1242 - sparse_categorical_accuracy: 0.5998 - val_loss: 0.9876 - val_sparse_categorical_accuracy: 0.6493
# Epoch 6/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1188 - sparse_categorical_accuracy: 0.6028 - val_loss: 0.9821 - val_sparse_categorical_accuracy: 0.6524
# Epoch 7/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1218 - sparse_categorical_accuracy: 0.6027 - val_loss: 0.9813 - val_sparse_categorical_accuracy: 0.6499
# Epoch 8/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1229 - sparse_categorical_accuracy: 0.6011 - val_loss: 0.9850 - val_sparse_categorical_accuracy: 0.6507
# Epoch 9/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1125 - sparse_categorical_accuracy: 0.6042 - val_loss: 0.9805 - val_sparse_categorical_accuracy: 0.6530
# Epoch 10/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1140 - sparse_categorical_accuracy: 0.6036 - val_loss: 0.9785 - val_sparse_categorical_accuracy: 0.6526
# Epoch 11/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1173 - sparse_categorical_accuracy: 0.6011 - val_loss: 0.9824 - val_sparse_categorical_accuracy: 0.6557
# Epoch 12/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1193 - sparse_categorical_accuracy: 0.6005 - val_loss: 0.9796 - val_sparse_categorical_accuracy: 0.6521
# Epoch 13/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1148 - sparse_categorical_accuracy: 0.6056 - val_loss: 0.9821 - val_sparse_categorical_accuracy: 0.6536
# Epoch 14/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1162 - sparse_categorical_accuracy: 0.6018 - val_loss: 0.9762 - val_sparse_categorical_accuracy: 0.6543
# Epoch 15/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1173 - sparse_categorical_accuracy: 0.6011 - val_loss: 0.9839 - val_sparse_categorical_accuracy: 0.6528
# Epoch 16/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1150 - sparse_categorical_accuracy: 0.6011 - val_loss: 0.9790 - val_sparse_categorical_accuracy: 0.6535
# Epoch 17/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1115 - sparse_categorical_accuracy: 0.6033 - val_loss: 0.9790 - val_sparse_categorical_accuracy: 0.6515
# Epoch 18/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.1170 - sparse_categorical_accuracy: 0.6019 - val_loss: 0.9894 - val_sparse_categorical_accuracy: 0.6490
# Epoch 19/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1112 - sparse_categorical_accuracy: 0.6045 - val_loss: 0.9786 - val_sparse_categorical_accuracy: 0.6534
# Epoch 20/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1128 - sparse_categorical_accuracy: 0.6039 - val_loss: 0.9766 - val_sparse_categorical_accuracy: 0.6539
# Epoch 21/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.1113 - sparse_categorical_accuracy: 0.6045 - val_loss: 0.9802 - val_sparse_categorical_accuracy: 0.6504
# Epoch 22/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.1118 - sparse_categorical_accuracy: 0.6054 - val_loss: 0.9811 - val_sparse_categorical_accuracy: 0.6507
# Epoch 23/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1096 - sparse_categorical_accuracy: 0.6053 - val_loss: 0.9800 - val_sparse_categorical_accuracy: 0.6502
# Epoch 24/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1109 - sparse_categorical_accuracy: 0.6044 - val_loss: 0.9767 - val_sparse_categorical_accuracy: 0.6547
# Epoch 25/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1090 - sparse_categorical_accuracy: 0.6066 - val_loss: 0.9755 - val_sparse_categorical_accuracy: 0.6527
# Epoch 26/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1062 - sparse_categorical_accuracy: 0.6085 - val_loss: 0.9807 - val_sparse_categorical_accuracy: 0.6543
# Epoch 27/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1095 - sparse_categorical_accuracy: 0.6061 - val_loss: 0.9770 - val_sparse_categorical_accuracy: 0.6556
# Epoch 28/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1037 - sparse_categorical_accuracy: 0.6062 - val_loss: 0.9692 - val_sparse_categorical_accuracy: 0.6555
# Epoch 29/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1081 - sparse_categorical_accuracy: 0.6073 - val_loss: 0.9731 - val_sparse_categorical_accuracy: 0.6581
# Epoch 30/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1043 - sparse_categorical_accuracy: 0.6067 - val_loss: 0.9756 - val_sparse_categorical_accuracy: 0.6556
# Epoch 31/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1085 - sparse_categorical_accuracy: 0.6036 - val_loss: 0.9752 - val_sparse_categorical_accuracy: 0.6538
# Epoch 32/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1092 - sparse_categorical_accuracy: 0.6055 - val_loss: 0.9693 - val_sparse_categorical_accuracy: 0.6581
# Epoch 33/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1059 - sparse_categorical_accuracy: 0.6049 - val_loss: 0.9699 - val_sparse_categorical_accuracy: 0.6526
# Epoch 34/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1095 - sparse_categorical_accuracy: 0.6047 - val_loss: 0.9704 - val_sparse_categorical_accuracy: 0.6548
# Epoch 35/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1040 - sparse_categorical_accuracy: 0.6097 - val_loss: 0.9786 - val_sparse_categorical_accuracy: 0.6544
# Epoch 36/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1063 - sparse_categorical_accuracy: 0.6072 - val_loss: 0.9710 - val_sparse_categorical_accuracy: 0.6548
# Epoch 37/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.1047 - sparse_categorical_accuracy: 0.6070 - val_loss: 0.9706 - val_sparse_categorical_accuracy: 0.6564
# Epoch 38/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0978 - sparse_categorical_accuracy: 0.6088 - val_loss: 0.9690 - val_sparse_categorical_accuracy: 0.6582
# Epoch 39/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.1000 - sparse_categorical_accuracy: 0.6074 - val_loss: 0.9685 - val_sparse_categorical_accuracy: 0.6575
# Epoch 40/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1013 - sparse_categorical_accuracy: 0.6091 - val_loss: 0.9718 - val_sparse_categorical_accuracy: 0.6538
# Epoch 41/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.1003 - sparse_categorical_accuracy: 0.6069 - val_loss: 0.9683 - val_sparse_categorical_accuracy: 0.6567
# Epoch 42/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1047 - sparse_categorical_accuracy: 0.6042 - val_loss: 0.9693 - val_sparse_categorical_accuracy: 0.6547
# Epoch 43/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1038 - sparse_categorical_accuracy: 0.6078 - val_loss: 0.9640 - val_sparse_categorical_accuracy: 0.6585
# Epoch 44/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0958 - sparse_categorical_accuracy: 0.6110 - val_loss: 0.9725 - val_sparse_categorical_accuracy: 0.6540
# Epoch 45/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0969 - sparse_categorical_accuracy: 0.6076 - val_loss: 0.9665 - val_sparse_categorical_accuracy: 0.6577
# Epoch 46/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1042 - sparse_categorical_accuracy: 0.6064 - val_loss: 0.9796 - val_sparse_categorical_accuracy: 0.6513
# Epoch 47/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0957 - sparse_categorical_accuracy: 0.6106 - val_loss: 0.9690 - val_sparse_categorical_accuracy: 0.6561
# Epoch 48/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0950 - sparse_categorical_accuracy: 0.6111 - val_loss: 0.9689 - val_sparse_categorical_accuracy: 0.6570
# Epoch 49/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1002 - sparse_categorical_accuracy: 0.6085 - val_loss: 0.9688 - val_sparse_categorical_accuracy: 0.6571
# Epoch 50/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0959 - sparse_categorical_accuracy: 0.6115 - val_loss: 0.9708 - val_sparse_categorical_accuracy: 0.6590
# Epoch 51/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1013 - sparse_categorical_accuracy: 0.6066 - val_loss: 0.9697 - val_sparse_categorical_accuracy: 0.6575
# Epoch 52/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0961 - sparse_categorical_accuracy: 0.6085 - val_loss: 0.9643 - val_sparse_categorical_accuracy: 0.6618
# Epoch 53/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0961 - sparse_categorical_accuracy: 0.6114 - val_loss: 0.9638 - val_sparse_categorical_accuracy: 0.6606
# Epoch 54/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0863 - sparse_categorical_accuracy: 0.6116 - val_loss: 0.9656 - val_sparse_categorical_accuracy: 0.6590
# Epoch 55/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0944 - sparse_categorical_accuracy: 0.6107 - val_loss: 0.9602 - val_sparse_categorical_accuracy: 0.6601
# Epoch 56/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0966 - sparse_categorical_accuracy: 0.6087 - val_loss: 0.9664 - val_sparse_categorical_accuracy: 0.6591
# Epoch 57/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0991 - sparse_categorical_accuracy: 0.6106 - val_loss: 0.9577 - val_sparse_categorical_accuracy: 0.6596
# Epoch 58/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0969 - sparse_categorical_accuracy: 0.6093 - val_loss: 0.9605 - val_sparse_categorical_accuracy: 0.6610
# Epoch 59/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0882 - sparse_categorical_accuracy: 0.6135 - val_loss: 0.9650 - val_sparse_categorical_accuracy: 0.6578
# Epoch 60/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0908 - sparse_categorical_accuracy: 0.6129 - val_loss: 0.9554 - val_sparse_categorical_accuracy: 0.6625
# Epoch 61/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0923 - sparse_categorical_accuracy: 0.6089 - val_loss: 0.9569 - val_sparse_categorical_accuracy: 0.6643
# Epoch 62/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0870 - sparse_categorical_accuracy: 0.6116 - val_loss: 0.9596 - val_sparse_categorical_accuracy: 0.6578
# Epoch 63/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0913 - sparse_categorical_accuracy: 0.6127 - val_loss: 0.9550 - val_sparse_categorical_accuracy: 0.6627
# Epoch 64/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0842 - sparse_categorical_accuracy: 0.6130 - val_loss: 0.9552 - val_sparse_categorical_accuracy: 0.6635
# Epoch 65/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0847 - sparse_categorical_accuracy: 0.6131 - val_loss: 0.9651 - val_sparse_categorical_accuracy: 0.6616
# Epoch 66/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0883 - sparse_categorical_accuracy: 0.6109 - val_loss: 0.9527 - val_sparse_categorical_accuracy: 0.6639
# Epoch 67/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0869 - sparse_categorical_accuracy: 0.6135 - val_loss: 0.9538 - val_sparse_categorical_accuracy: 0.6591
# Epoch 68/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0903 - sparse_categorical_accuracy: 0.6115 - val_loss: 0.9522 - val_sparse_categorical_accuracy: 0.6640
# Epoch 69/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 1.0866 - sparse_categorical_accuracy: 0.6135 - val_loss: 0.9568 - val_sparse_categorical_accuracy: 0.6627
# Epoch 70/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 1.0865 - sparse_categorical_accuracy: 0.6155 - val_loss: 0.9573 - val_sparse_categorical_accuracy: 0.6601
# Epoch 71/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0818 - sparse_categorical_accuracy: 0.6137 - val_loss: 0.9519 - val_sparse_categorical_accuracy: 0.6642
# Epoch 72/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0869 - sparse_categorical_accuracy: 0.6130 - val_loss: 0.9556 - val_sparse_categorical_accuracy: 0.6580
# Epoch 73/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0880 - sparse_categorical_accuracy: 0.6099 - val_loss: 0.9548 - val_sparse_categorical_accuracy: 0.6650
# Epoch 74/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 1.0879 - sparse_categorical_accuracy: 0.6133 - val_loss: 0.9577 - val_sparse_categorical_accuracy: 0.6645
# Epoch 75/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0894 - sparse_categorical_accuracy: 0.6143 - val_loss: 0.9584 - val_sparse_categorical_accuracy: 0.6616
# Epoch 76/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0843 - sparse_categorical_accuracy: 0.6133 - val_loss: 0.9540 - val_sparse_categorical_accuracy: 0.6628
# Epoch 77/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0845 - sparse_categorical_accuracy: 0.6146 - val_loss: 0.9513 - val_sparse_categorical_accuracy: 0.6629
# Epoch 78/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0814 - sparse_categorical_accuracy: 0.6136 - val_loss: 0.9515 - val_sparse_categorical_accuracy: 0.6618
# Epoch 79/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0836 - sparse_categorical_accuracy: 0.6165 - val_loss: 0.9516 - val_sparse_categorical_accuracy: 0.6643
# Epoch 80/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0797 - sparse_categorical_accuracy: 0.6151 - val_loss: 0.9544 - val_sparse_categorical_accuracy: 0.6626
# Epoch 81/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0814 - sparse_categorical_accuracy: 0.6162 - val_loss: 0.9559 - val_sparse_categorical_accuracy: 0.6624
# Epoch 82/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0798 - sparse_categorical_accuracy: 0.6159 - val_loss: 0.9506 - val_sparse_categorical_accuracy: 0.6641
# Epoch 83/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0818 - sparse_categorical_accuracy: 0.6150 - val_loss: 0.9529 - val_sparse_categorical_accuracy: 0.6620
# Epoch 84/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0790 - sparse_categorical_accuracy: 0.6163 - val_loss: 0.9563 - val_sparse_categorical_accuracy: 0.6606
# Epoch 85/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0786 - sparse_categorical_accuracy: 0.6167 - val_loss: 0.9509 - val_sparse_categorical_accuracy: 0.6615
# Epoch 86/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0794 - sparse_categorical_accuracy: 0.6170 - val_loss: 0.9499 - val_sparse_categorical_accuracy: 0.6684
# Epoch 87/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0798 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.9529 - val_sparse_categorical_accuracy: 0.6653
# Epoch 88/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0774 - sparse_categorical_accuracy: 0.6170 - val_loss: 0.9433 - val_sparse_categorical_accuracy: 0.6674
# Epoch 89/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0778 - sparse_categorical_accuracy: 0.6166 - val_loss: 0.9535 - val_sparse_categorical_accuracy: 0.6619
# Epoch 90/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0746 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.9524 - val_sparse_categorical_accuracy: 0.6630
# Epoch 91/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0755 - sparse_categorical_accuracy: 0.6176 - val_loss: 0.9529 - val_sparse_categorical_accuracy: 0.6608
# Epoch 92/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0760 - sparse_categorical_accuracy: 0.6169 - val_loss: 0.9469 - val_sparse_categorical_accuracy: 0.6643
# Epoch 93/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0734 - sparse_categorical_accuracy: 0.6180 - val_loss: 0.9520 - val_sparse_categorical_accuracy: 0.6655
# Epoch 94/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0792 - sparse_categorical_accuracy: 0.6143 - val_loss: 0.9546 - val_sparse_categorical_accuracy: 0.6636
# Epoch 95/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0768 - sparse_categorical_accuracy: 0.6158 - val_loss: 0.9530 - val_sparse_categorical_accuracy: 0.6672
# Epoch 96/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0759 - sparse_categorical_accuracy: 0.6162 - val_loss: 0.9406 - val_sparse_categorical_accuracy: 0.6707
# Epoch 97/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0733 - sparse_categorical_accuracy: 0.6194 - val_loss: 0.9505 - val_sparse_categorical_accuracy: 0.6649
# Epoch 98/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0731 - sparse_categorical_accuracy: 0.6184 - val_loss: 0.9465 - val_sparse_categorical_accuracy: 0.6674
# Epoch 99/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0755 - sparse_categorical_accuracy: 0.6167 - val_loss: 0.9519 - val_sparse_categorical_accuracy: 0.6607
# Epoch 100/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0709 - sparse_categorical_accuracy: 0.6189 - val_loss: 0.9410 - val_sparse_categorical_accuracy: 0.6678
# Epoch 101/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0748 - sparse_categorical_accuracy: 0.6171 - val_loss: 0.9388 - val_sparse_categorical_accuracy: 0.6696
# Epoch 102/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0648 - sparse_categorical_accuracy: 0.6210 - val_loss: 0.9435 - val_sparse_categorical_accuracy: 0.6674
# Epoch 103/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0751 - sparse_categorical_accuracy: 0.6154 - val_loss: 0.9373 - val_sparse_categorical_accuracy: 0.6712
# Epoch 104/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0703 - sparse_categorical_accuracy: 0.6180 - val_loss: 0.9431 - val_sparse_categorical_accuracy: 0.6677
# Epoch 105/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0689 - sparse_categorical_accuracy: 0.6213 - val_loss: 0.9420 - val_sparse_categorical_accuracy: 0.6655
# Epoch 106/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0651 - sparse_categorical_accuracy: 0.6199 - val_loss: 0.9426 - val_sparse_categorical_accuracy: 0.6689
# Epoch 107/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0683 - sparse_categorical_accuracy: 0.6187 - val_loss: 0.9440 - val_sparse_categorical_accuracy: 0.6652
# Epoch 108/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.0618 - sparse_categorical_accuracy: 0.6215 - val_loss: 0.9426 - val_sparse_categorical_accuracy: 0.6694
# Epoch 109/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0665 - sparse_categorical_accuracy: 0.6199 - val_loss: 0.9429 - val_sparse_categorical_accuracy: 0.6675
# Epoch 110/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0671 - sparse_categorical_accuracy: 0.6200 - val_loss: 0.9440 - val_sparse_categorical_accuracy: 0.6710
# Epoch 111/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0643 - sparse_categorical_accuracy: 0.6197 - val_loss: 0.9407 - val_sparse_categorical_accuracy: 0.6707
# Epoch 112/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0670 - sparse_categorical_accuracy: 0.6207 - val_loss: 0.9454 - val_sparse_categorical_accuracy: 0.6711
# Epoch 113/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0660 - sparse_categorical_accuracy: 0.6213 - val_loss: 0.9407 - val_sparse_categorical_accuracy: 0.6688
# Epoch 114/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0633 - sparse_categorical_accuracy: 0.6218 - val_loss: 0.9387 - val_sparse_categorical_accuracy: 0.6690
# Epoch 115/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0652 - sparse_categorical_accuracy: 0.6216 - val_loss: 0.9395 - val_sparse_categorical_accuracy: 0.6711
# Epoch 116/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0641 - sparse_categorical_accuracy: 0.6200 - val_loss: 0.9404 - val_sparse_categorical_accuracy: 0.6666
# Epoch 117/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0644 - sparse_categorical_accuracy: 0.6211 - val_loss: 0.9369 - val_sparse_categorical_accuracy: 0.6698
# Epoch 118/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0634 - sparse_categorical_accuracy: 0.6222 - val_loss: 0.9374 - val_sparse_categorical_accuracy: 0.6718
# Epoch 119/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0648 - sparse_categorical_accuracy: 0.6218 - val_loss: 0.9358 - val_sparse_categorical_accuracy: 0.6677
# Epoch 120/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.0632 - sparse_categorical_accuracy: 0.6241 - val_loss: 0.9410 - val_sparse_categorical_accuracy: 0.6691
# Epoch 121/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0591 - sparse_categorical_accuracy: 0.6224 - val_loss: 0.9400 - val_sparse_categorical_accuracy: 0.6706
# Epoch 122/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0576 - sparse_categorical_accuracy: 0.6218 - val_loss: 0.9415 - val_sparse_categorical_accuracy: 0.6700
# Epoch 123/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0599 - sparse_categorical_accuracy: 0.6212 - val_loss: 0.9315 - val_sparse_categorical_accuracy: 0.6689
# Epoch 124/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0547 - sparse_categorical_accuracy: 0.6246 - val_loss: 0.9391 - val_sparse_categorical_accuracy: 0.6686
# Epoch 125/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0608 - sparse_categorical_accuracy: 0.6198 - val_loss: 0.9302 - val_sparse_categorical_accuracy: 0.6699
# Epoch 126/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0646 - sparse_categorical_accuracy: 0.6213 - val_loss: 0.9341 - val_sparse_categorical_accuracy: 0.6675
# Epoch 127/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0612 - sparse_categorical_accuracy: 0.6224 - val_loss: 0.9323 - val_sparse_categorical_accuracy: 0.6732
# Epoch 128/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0619 - sparse_categorical_accuracy: 0.6207 - val_loss: 0.9353 - val_sparse_categorical_accuracy: 0.6722
# Epoch 129/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0570 - sparse_categorical_accuracy: 0.6254 - val_loss: 0.9345 - val_sparse_categorical_accuracy: 0.6694
# Epoch 130/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0503 - sparse_categorical_accuracy: 0.6255 - val_loss: 0.9319 - val_sparse_categorical_accuracy: 0.6703
# Epoch 131/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0513 - sparse_categorical_accuracy: 0.6255 - val_loss: 0.9357 - val_sparse_categorical_accuracy: 0.6682
# Epoch 132/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0573 - sparse_categorical_accuracy: 0.6244 - val_loss: 0.9364 - val_sparse_categorical_accuracy: 0.6662
# Epoch 133/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0576 - sparse_categorical_accuracy: 0.6217 - val_loss: 0.9303 - val_sparse_categorical_accuracy: 0.6701
# Epoch 134/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0572 - sparse_categorical_accuracy: 0.6220 - val_loss: 0.9353 - val_sparse_categorical_accuracy: 0.6721
# Epoch 135/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0574 - sparse_categorical_accuracy: 0.6258 - val_loss: 0.9379 - val_sparse_categorical_accuracy: 0.6678
# Epoch 136/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0491 - sparse_categorical_accuracy: 0.6288 - val_loss: 0.9336 - val_sparse_categorical_accuracy: 0.6696
# Epoch 137/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0504 - sparse_categorical_accuracy: 0.6256 - val_loss: 0.9348 - val_sparse_categorical_accuracy: 0.6702
# Epoch 138/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0542 - sparse_categorical_accuracy: 0.6248 - val_loss: 0.9330 - val_sparse_categorical_accuracy: 0.6696
# Epoch 139/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0489 - sparse_categorical_accuracy: 0.6268 - val_loss: 0.9308 - val_sparse_categorical_accuracy: 0.6736
# Epoch 140/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0477 - sparse_categorical_accuracy: 0.6275 - val_loss: 0.9320 - val_sparse_categorical_accuracy: 0.6712
# Epoch 141/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0514 - sparse_categorical_accuracy: 0.6290 - val_loss: 0.9313 - val_sparse_categorical_accuracy: 0.6716
# Epoch 142/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0557 - sparse_categorical_accuracy: 0.6206 - val_loss: 0.9321 - val_sparse_categorical_accuracy: 0.6722
# Epoch 143/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0529 - sparse_categorical_accuracy: 0.6223 - val_loss: 0.9294 - val_sparse_categorical_accuracy: 0.6735
# Epoch 144/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0525 - sparse_categorical_accuracy: 0.6270 - val_loss: 0.9306 - val_sparse_categorical_accuracy: 0.6704
# Epoch 145/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0508 - sparse_categorical_accuracy: 0.6274 - val_loss: 0.9303 - val_sparse_categorical_accuracy: 0.6748
# Epoch 146/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0479 - sparse_categorical_accuracy: 0.6257 - val_loss: 0.9296 - val_sparse_categorical_accuracy: 0.6726
# Epoch 147/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0499 - sparse_categorical_accuracy: 0.6279 - val_loss: 0.9361 - val_sparse_categorical_accuracy: 0.6669
# Epoch 148/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0499 - sparse_categorical_accuracy: 0.6251 - val_loss: 0.9293 - val_sparse_categorical_accuracy: 0.6742
# Epoch 149/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.0521 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.9300 - val_sparse_categorical_accuracy: 0.6719
# Epoch 150/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0516 - sparse_categorical_accuracy: 0.6232 - val_loss: 0.9301 - val_sparse_categorical_accuracy: 0.6710
# Epoch 151/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0449 - sparse_categorical_accuracy: 0.6275 - val_loss: 0.9284 - val_sparse_categorical_accuracy: 0.6727
# Epoch 152/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0465 - sparse_categorical_accuracy: 0.6278 - val_loss: 0.9234 - val_sparse_categorical_accuracy: 0.6758
# Epoch 153/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0430 - sparse_categorical_accuracy: 0.6296 - val_loss: 0.9296 - val_sparse_categorical_accuracy: 0.6740
# Epoch 154/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0481 - sparse_categorical_accuracy: 0.6269 - val_loss: 0.9286 - val_sparse_categorical_accuracy: 0.6706
# Epoch 155/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0522 - sparse_categorical_accuracy: 0.6232 - val_loss: 0.9353 - val_sparse_categorical_accuracy: 0.6685
# Epoch 156/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0516 - sparse_categorical_accuracy: 0.6276 - val_loss: 0.9276 - val_sparse_categorical_accuracy: 0.6709
# Epoch 157/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0426 - sparse_categorical_accuracy: 0.6281 - val_loss: 0.9241 - val_sparse_categorical_accuracy: 0.6701
# Epoch 158/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0480 - sparse_categorical_accuracy: 0.6262 - val_loss: 0.9290 - val_sparse_categorical_accuracy: 0.6703
# Epoch 159/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0416 - sparse_categorical_accuracy: 0.6297 - val_loss: 0.9241 - val_sparse_categorical_accuracy: 0.6718
# Epoch 160/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0398 - sparse_categorical_accuracy: 0.6297 - val_loss: 0.9262 - val_sparse_categorical_accuracy: 0.6752
# Epoch 161/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0422 - sparse_categorical_accuracy: 0.6314 - val_loss: 0.9231 - val_sparse_categorical_accuracy: 0.6758
# Epoch 162/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0427 - sparse_categorical_accuracy: 0.6293 - val_loss: 0.9298 - val_sparse_categorical_accuracy: 0.6719
# Epoch 163/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0470 - sparse_categorical_accuracy: 0.6266 - val_loss: 0.9241 - val_sparse_categorical_accuracy: 0.6718
# Epoch 164/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0457 - sparse_categorical_accuracy: 0.6275 - val_loss: 0.9285 - val_sparse_categorical_accuracy: 0.6737
# Epoch 165/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0422 - sparse_categorical_accuracy: 0.6289 - val_loss: 0.9231 - val_sparse_categorical_accuracy: 0.6749
# Epoch 166/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0420 - sparse_categorical_accuracy: 0.6301 - val_loss: 0.9227 - val_sparse_categorical_accuracy: 0.6770
# Epoch 167/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0504 - sparse_categorical_accuracy: 0.6238 - val_loss: 0.9229 - val_sparse_categorical_accuracy: 0.6756
# Epoch 168/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0420 - sparse_categorical_accuracy: 0.6280 - val_loss: 0.9203 - val_sparse_categorical_accuracy: 0.6775
# Epoch 169/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0402 - sparse_categorical_accuracy: 0.6279 - val_loss: 0.9291 - val_sparse_categorical_accuracy: 0.6693
# Epoch 170/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0432 - sparse_categorical_accuracy: 0.6264 - val_loss: 0.9231 - val_sparse_categorical_accuracy: 0.6733
# Epoch 171/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0523 - sparse_categorical_accuracy: 0.6239 - val_loss: 0.9211 - val_sparse_categorical_accuracy: 0.6717
# Epoch 172/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0434 - sparse_categorical_accuracy: 0.6269 - val_loss: 0.9289 - val_sparse_categorical_accuracy: 0.6730
# Epoch 173/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0427 - sparse_categorical_accuracy: 0.6291 - val_loss: 0.9215 - val_sparse_categorical_accuracy: 0.6737
# Epoch 174/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0387 - sparse_categorical_accuracy: 0.6300 - val_loss: 0.9219 - val_sparse_categorical_accuracy: 0.6776
# Epoch 175/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0353 - sparse_categorical_accuracy: 0.6335 - val_loss: 0.9249 - val_sparse_categorical_accuracy: 0.6747
# Epoch 176/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0405 - sparse_categorical_accuracy: 0.6308 - val_loss: 0.9233 - val_sparse_categorical_accuracy: 0.6766
# Epoch 177/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0357 - sparse_categorical_accuracy: 0.6305 - val_loss: 0.9198 - val_sparse_categorical_accuracy: 0.6734
# Epoch 178/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0361 - sparse_categorical_accuracy: 0.6307 - val_loss: 0.9207 - val_sparse_categorical_accuracy: 0.6767
# Epoch 179/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0394 - sparse_categorical_accuracy: 0.6283 - val_loss: 0.9227 - val_sparse_categorical_accuracy: 0.6762
# Epoch 180/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0326 - sparse_categorical_accuracy: 0.6328 - val_loss: 0.9267 - val_sparse_categorical_accuracy: 0.6690
# Epoch 181/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0362 - sparse_categorical_accuracy: 0.6307 - val_loss: 0.9169 - val_sparse_categorical_accuracy: 0.6765
# Epoch 182/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0377 - sparse_categorical_accuracy: 0.6313 - val_loss: 0.9202 - val_sparse_categorical_accuracy: 0.6754
# Epoch 183/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0368 - sparse_categorical_accuracy: 0.6310 - val_loss: 0.9181 - val_sparse_categorical_accuracy: 0.6748
# Epoch 184/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0330 - sparse_categorical_accuracy: 0.6309 - val_loss: 0.9178 - val_sparse_categorical_accuracy: 0.6762
# Epoch 185/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0338 - sparse_categorical_accuracy: 0.6311 - val_loss: 0.9156 - val_sparse_categorical_accuracy: 0.6778
# Epoch 186/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0350 - sparse_categorical_accuracy: 0.6340 - val_loss: 0.9205 - val_sparse_categorical_accuracy: 0.6752
# Epoch 187/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0330 - sparse_categorical_accuracy: 0.6325 - val_loss: 0.9186 - val_sparse_categorical_accuracy: 0.6758
# Epoch 188/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0345 - sparse_categorical_accuracy: 0.6310 - val_loss: 0.9165 - val_sparse_categorical_accuracy: 0.6768
# Epoch 189/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0308 - sparse_categorical_accuracy: 0.6316 - val_loss: 0.9223 - val_sparse_categorical_accuracy: 0.6718
# Epoch 190/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0302 - sparse_categorical_accuracy: 0.6325 - val_loss: 0.9085 - val_sparse_categorical_accuracy: 0.6817
# Epoch 191/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0295 - sparse_categorical_accuracy: 0.6326 - val_loss: 0.9157 - val_sparse_categorical_accuracy: 0.6773
# Epoch 192/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0329 - sparse_categorical_accuracy: 0.6308 - val_loss: 0.9148 - val_sparse_categorical_accuracy: 0.6764
# Epoch 193/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0255 - sparse_categorical_accuracy: 0.6335 - val_loss: 0.9215 - val_sparse_categorical_accuracy: 0.6734
# Epoch 194/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0292 - sparse_categorical_accuracy: 0.6325 - val_loss: 0.9155 - val_sparse_categorical_accuracy: 0.6770
# Epoch 195/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0334 - sparse_categorical_accuracy: 0.6311 - val_loss: 0.9088 - val_sparse_categorical_accuracy: 0.6766
# Epoch 196/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0299 - sparse_categorical_accuracy: 0.6323 - val_loss: 0.9131 - val_sparse_categorical_accuracy: 0.6790
# Epoch 197/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0302 - sparse_categorical_accuracy: 0.6349 - val_loss: 0.9111 - val_sparse_categorical_accuracy: 0.6747
# Epoch 198/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0336 - sparse_categorical_accuracy: 0.6318 - val_loss: 0.9172 - val_sparse_categorical_accuracy: 0.6773
# Epoch 199/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0266 - sparse_categorical_accuracy: 0.6344 - val_loss: 0.9178 - val_sparse_categorical_accuracy: 0.6722
# Epoch 200/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0282 - sparse_categorical_accuracy: 0.6315 - val_loss: 0.9170 - val_sparse_categorical_accuracy: 0.6746

# %%
for key in even_more_history.history:
    history.history[key].extend(even_more_history.history[key])
show_training_curves(history)
